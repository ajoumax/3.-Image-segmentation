# %% [markdown]
# # Part 3. Tensorflow tutorial - Image segmentation

# %% [markdown]
# ### Goal of this tutorial:
# ###     Build and train a model which segments aorta in CT images

# %% [markdown]
# ## (1) Labelling train images

# %%
# Create ground-truth mask image on Slicer software

# %%
import nibabel as nb 
import numpy as np

import matplotlib.pyplot as plt
import os
import pandas as pd 
import cv2 

#from keras.models import Sequential
#import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import Sequence

import tensorflow as tf
# %matplotlib inline

# %%
for dirname, _, filenames in os.walk('./aorta-ct-scans'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./aorta-ct-scans\aorta_metadata.csv
# ./aorta-ct-scans\CT (51).nii
# ./aorta-ct-scans\ct_segmentation_result.csv
# ./aorta-ct-scans\Segmentation (51).nii
# ./aorta-ct-scans\local_ct_data\0000\CT0.nii
# ./aorta-ct-scans\local_ct_data\0000\PET.nii
# ./aorta-ct-scans\local_ct_data\0000\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0001\CT1.nii
# ./aorta-ct-scans\local_ct_data\0001\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0002\CT2.nii
# ./aorta-ct-scans\local_ct_data\0002\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0003\CT3.nii
# ./aorta-ct-scans\local_ct_data\0003\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0004\CT4.nii
# ./aorta-ct-scans\local_ct_data\0004\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0005\CT5.nii
# ./aorta-ct-scans\local_ct_data\0005\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0006\CT6.nii
# ./aorta-ct-scans\local_ct_data\0006\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0007\CT7.nii
# ./aorta-ct-scans\local_ct_data\0007\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0008\CT8.nii
# ./aorta-ct-scans\local_ct_data\0008\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0009\CT9.nii
# ./aorta-ct-scans\local_ct_data\0009\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0010\CT10.nii
# ./aorta-ct-scans\local_ct_data\0010\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0011\CT.nii
# ./aorta-ct-scans\local_ct_data\0011\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0012\CT.nii
# ./aorta-ct-scans\local_ct_data\0012\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0013\CT.nii
# ./aorta-ct-scans\local_ct_data\0013\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0014\CT.nii
# ./aorta-ct-scans\local_ct_data\0014\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0015\CT.nii
# ./aorta-ct-scans\local_ct_data\0015\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0016\CT.nii
# ./aorta-ct-scans\local_ct_data\0016\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0017\CT.nii
# ./aorta-ct-scans\local_ct_data\0017\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0018\CT.nii
# ./aorta-ct-scans\local_ct_data\0018\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0019\CT.nii
# ./aorta-ct-scans\local_ct_data\0019\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0020\CT.nii
# ./aorta-ct-scans\local_ct_data\0020\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0021\CT.nii
# ./aorta-ct-scans\local_ct_data\0021\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0022\CT.nii
# ./aorta-ct-scans\local_ct_data\0022\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0023\CT.nii
# ./aorta-ct-scans\local_ct_data\0023\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0024\CT.nii
# ./aorta-ct-scans\local_ct_data\0024\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0025\CT.nii
# ./aorta-ct-scans\local_ct_data\0025\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0026\CT.nii
# ./aorta-ct-scans\local_ct_data\0026\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0027\CT.nii
# ./aorta-ct-scans\local_ct_data\0027\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0028\CT.nii
# ./aorta-ct-scans\local_ct_data\0028\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0029\CT.nii
# ./aorta-ct-scans\local_ct_data\0029\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0030\CT.nii
# ./aorta-ct-scans\local_ct_data\0030\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0031\CT.nii
# ./aorta-ct-scans\local_ct_data\0031\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0032\CT.nii
# ./aorta-ct-scans\local_ct_data\0032\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0033\CT.nii
# ./aorta-ct-scans\local_ct_data\0033\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0034\CT.nii
# ./aorta-ct-scans\local_ct_data\0034\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0035\CT.nii
# ./aorta-ct-scans\local_ct_data\0035\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0036\CT.nii
# ./aorta-ct-scans\local_ct_data\0036\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0037\CT.nii
# ./aorta-ct-scans\local_ct_data\0037\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0038\CT.nii
# ./aorta-ct-scans\local_ct_data\0038\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0039\CT.nii
# ./aorta-ct-scans\local_ct_data\0039\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0040\CT.nii
# ./aorta-ct-scans\local_ct_data\0040\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0041\CT.nii
# ./aorta-ct-scans\local_ct_data\0041\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0042\CT.nii
# ./aorta-ct-scans\local_ct_data\0042\Segmentation_2.nii
# ./aorta-ct-scans\local_ct_data\0043\CT.nii
# ./aorta-ct-scans\local_ct_data\0043\Segmentation_4.nii
# ./aorta-ct-scans\local_ct_data\0044\CT.nii
# ./aorta-ct-scans\local_ct_data\0044\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0045\CT.nii
# ./aorta-ct-scans\local_ct_data\0045\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0046\CT.nii
# ./aorta-ct-scans\local_ct_data\0046\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0047\CT.nii
# ./aorta-ct-scans\local_ct_data\0047\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0048\CT.nii
# ./aorta-ct-scans\local_ct_data\0048\Segmentation_3.nii
# ./aorta-ct-scans\local_ct_data\0049\CT49.nii
# ./aorta-ct-scans\local_ct_data\0049\Segmentation.nii
# ./aorta-ct-scans\local_ct_data\0050\CT50.nii
# ./aorta-ct-scans\local_ct_data\0050\Segmentation_2.nii
# ./aorta-ct-scans\local_ct_data - copy\0000\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0000\PET.nii
# ./aorta-ct-scans\local_ct_data - copy\0000\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0001\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0001\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0002\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0002\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0003\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0003\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0004\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0004\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0005\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0005\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0006\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0006\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0007\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0007\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0008\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0008\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0009\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0009\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0010\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0010\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0011\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0011\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0012\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0012\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0013\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0013\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0014\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0014\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0015\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0015\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0016\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0016\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0017\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0017\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0018\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0018\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0019\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0019\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0020\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0020\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0021\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0021\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0022\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0022\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0023\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0023\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0024\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0024\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0025\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0025\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0026\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0026\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0027\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0027\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0028\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0028\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0029\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0029\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0030\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0030\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0031\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0031\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0032\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0032\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0033\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0033\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0034\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0034\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0035\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0035\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0036\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0036\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0037\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0037\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0038\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0038\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0039\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0039\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0040\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0040\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0041\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0041\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0042\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0042\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0043\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0043\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0044\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0044\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0045\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0045\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0046\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0046\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0047\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0047\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0048\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0048\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0049\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0049\Segmentation.nii
# ./aorta-ct-scans\local_ct_data - copy\0050\CT.nii
# ./aorta-ct-scans\local_ct_data - copy\0050\Segmentation.nii
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10000.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10001.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10002.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10003.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10004.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10005.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10006.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10007.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10008.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10009.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10010.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10011.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10012.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10013.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10014.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10015.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10016.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10017.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10018.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10019.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10020.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10021.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10022.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10023.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10024.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10025.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10026.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10027.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10028.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10029.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10030.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10031.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10032.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10033.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10034.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10035.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10036.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10037.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10038.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10039.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10040.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10041.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10042.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10043.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10044.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10045.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10046.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10047.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10048.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10049.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10050.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10051.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10052.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10053.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10054.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10055.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10056.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10057.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10058.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10059.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10060.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10061.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10062.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10063.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10064.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10065.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10066.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10067.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10068.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10069.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10070.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10071.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10072.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10073.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10074.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10075.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10076.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10077.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10078.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10079.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10080.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10081.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10082.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10083.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10084.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10085.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10086.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10087.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10088.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10089.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10090.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10091.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10092.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10093.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10094.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10095.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10096.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10097.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10098.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10099.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10100.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10101.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10102.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10103.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10104.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10105.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10106.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10107.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10108.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10109.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10110.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10111.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10112.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10113.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10114.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10115.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10116.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10117.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10118.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10119.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10120.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10121.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10122.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10123.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10124.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10125.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10126.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10127.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10128.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10129.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10130.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10131.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10132.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10133.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10134.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10135.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10136.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10137.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10138.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10139.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10140.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10141.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10142.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10143.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10144.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10145.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10146.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10147.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10148.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10149.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10150.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10151.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10152.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10153.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10154.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10155.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10156.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10157.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10158.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10159.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10160.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10161.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10162.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10163.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10164.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10165.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10166.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10167.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10168.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10169.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10170.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10171.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10172.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10173.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10174.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10175.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10176.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10177.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10178.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10179.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10180.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10181.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10182.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10183.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10184.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10185.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10186.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10187.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10188.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10189.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10190.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10191.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10192.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10193.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10194.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10195.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10196.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10197.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10198.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10199.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10200.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10201.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10202.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10203.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10204.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10205.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10206.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10207.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10208.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10209.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10210.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10211.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10212.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10213.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10214.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10215.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10216.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10217.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10218.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10219.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10220.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10221.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10222.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10223.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10224.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10225.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10226.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10227.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10228.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10229.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10230.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10231.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10232.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10233.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10234.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10235.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10236.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10237.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10238.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10239.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10240.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10241.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10242.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10243.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10244.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10245.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10246.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10247.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10248.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10249.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10250.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10251.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10252.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10253.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10254.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10255.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10256.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10257.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10258.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10259.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10260.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10261.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10262.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10263.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10264.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10265.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10266.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10267.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10268.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10269.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10270.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10271.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10272.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10273.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10274.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10275.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10276.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10277.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10278.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10279.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10280.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10281.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10282.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10283.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10284.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10285.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10286.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10287.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10288.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10289.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10290.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10291.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10292.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10293.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10294.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10295.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10296.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10297.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10298.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10299.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10300.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10301.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10302.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10303.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10304.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10305.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10306.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10307.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10308.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10309.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10310.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10311.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10312.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10313.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10314.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10315.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10316.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10317.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10318.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10319.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10320.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10321.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10322.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10323.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10324.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10325.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10326.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10327.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10328.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10329.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10330.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10331.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10332.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10333.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0195902c\CT\10334.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10000.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10001.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10002.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10003.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10004.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10005.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10006.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10007.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10008.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10009.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10010.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10011.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10012.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10013.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10014.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10015.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10016.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10017.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10018.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10019.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10020.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10021.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10022.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10023.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10024.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10025.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10026.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10027.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10028.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10029.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10030.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10031.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10032.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10033.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10034.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10035.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10036.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10037.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10038.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10039.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10040.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10041.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10042.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10043.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10044.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10045.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10046.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10047.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10048.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10049.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10050.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10051.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10052.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10053.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10054.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10055.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10056.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10057.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10058.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10059.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10060.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10061.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10062.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10063.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10064.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10065.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10066.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10067.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10068.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10069.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10070.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10071.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10072.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10073.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10074.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10075.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10076.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10077.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10078.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10079.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10080.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10081.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10082.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10083.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10084.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10085.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10086.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10087.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10088.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10089.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10090.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10091.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10092.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10093.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10094.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10095.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10096.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10097.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10098.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10099.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10100.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10101.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10102.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10103.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10104.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10105.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10106.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10107.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10108.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10109.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10110.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10111.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10112.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10113.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10114.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10115.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10116.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10117.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10118.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10119.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10120.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10121.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10122.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10123.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10124.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10125.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10126.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10127.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10128.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10129.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10130.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10131.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10132.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10133.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10134.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10135.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10136.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10137.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10138.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10139.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10140.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10141.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10142.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10143.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10144.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10145.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10146.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0203215c\CT\10147.dcm
# ...
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10170.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10171.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10172.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10173.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10174.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10175.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10176.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10177.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10178.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10179.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10180.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10181.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10182.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10183.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10184.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10185.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10186.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10187.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10188.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10189.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10190.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10191.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10192.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10193.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10194.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10195.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10196.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10197.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10198.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10199.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10200.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10201.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10202.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10203.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10204.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10205.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10206.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10207.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10208.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10209.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10210.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10211.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10212.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10213.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10214.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10215.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10216.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10217.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10218.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10219.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10220.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10221.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10222.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10223.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10224.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10225.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10226.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10227.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10228.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10229.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10230.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10231.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10232.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10233.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10234.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10235.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10236.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10237.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10238.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10239.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10240.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10241.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10242.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10243.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10244.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10245.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10246.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10247.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10248.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10249.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10250.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10251.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10252.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10253.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10254.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10255.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10256.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10257.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10258.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10259.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10260.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10261.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10262.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10263.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10264.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10265.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10266.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10267.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10268.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10269.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10270.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10271.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10272.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10273.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10274.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10275.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10276.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10277.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10278.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10279.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10280.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10281.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10282.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10283.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10284.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10285.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10286.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10287.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10288.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10289.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10290.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10291.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10292.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10293.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10294.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10295.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10296.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10297.dcm
# ./aorta-ct-scans\local_ct_data_not_labeled\not_labeled\0286353c\CT\10298.dcm
# ./aorta-ct-scans\local_ct_total_data\CT (1).nii
# ./aorta-ct-scans\local_ct_total_data\CT (10).nii
# ./aorta-ct-scans\local_ct_total_data\CT (11).nii
# ./aorta-ct-scans\local_ct_total_data\CT (12).nii
# ./aorta-ct-scans\local_ct_total_data\CT (13).nii
# ./aorta-ct-scans\local_ct_total_data\CT (14).nii
# ./aorta-ct-scans\local_ct_total_data\CT (15).nii
# ./aorta-ct-scans\local_ct_total_data\CT (16).nii
# ./aorta-ct-scans\local_ct_total_data\CT (17).nii
# ./aorta-ct-scans\local_ct_total_data\CT (18).nii
# ./aorta-ct-scans\local_ct_total_data\CT (19).nii
# ./aorta-ct-scans\local_ct_total_data\CT (2).nii
# ./aorta-ct-scans\local_ct_total_data\CT (20).nii
# ./aorta-ct-scans\local_ct_total_data\CT (21).nii
# ./aorta-ct-scans\local_ct_total_data\CT (22).nii
# ./aorta-ct-scans\local_ct_total_data\CT (23).nii
# ./aorta-ct-scans\local_ct_total_data\CT (24).nii
# ./aorta-ct-scans\local_ct_total_data\CT (25).nii
# ./aorta-ct-scans\local_ct_total_data\CT (26).nii
# ./aorta-ct-scans\local_ct_total_data\CT (27).nii
# ./aorta-ct-scans\local_ct_total_data\CT (28).nii
# ./aorta-ct-scans\local_ct_total_data\CT (29).nii
# ./aorta-ct-scans\local_ct_total_data\CT (3).nii
# ./aorta-ct-scans\local_ct_total_data\CT (30).nii
# ./aorta-ct-scans\local_ct_total_data\CT (31).nii
# ./aorta-ct-scans\local_ct_total_data\CT (32).nii
# ./aorta-ct-scans\local_ct_total_data\CT (33).nii
# ./aorta-ct-scans\local_ct_total_data\CT (34).nii
# ./aorta-ct-scans\local_ct_total_data\CT (35).nii
# ./aorta-ct-scans\local_ct_total_data\CT (36).nii
# ./aorta-ct-scans\local_ct_total_data\CT (37).nii
# ./aorta-ct-scans\local_ct_total_data\CT (38).nii
# ./aorta-ct-scans\local_ct_total_data\CT (39).nii
# ./aorta-ct-scans\local_ct_total_data\CT (4).nii
# ./aorta-ct-scans\local_ct_total_data\CT (40).nii
# ./aorta-ct-scans\local_ct_total_data\CT (41).nii
# ./aorta-ct-scans\local_ct_total_data\CT (42).nii
# ./aorta-ct-scans\local_ct_total_data\CT (43).nii
# ./aorta-ct-scans\local_ct_total_data\CT (44).nii
# ./aorta-ct-scans\local_ct_total_data\CT (45).nii
# ./aorta-ct-scans\local_ct_total_data\CT (46).nii
# ./aorta-ct-scans\local_ct_total_data\CT (47).nii
# ./aorta-ct-scans\local_ct_total_data\CT (48).nii
# ./aorta-ct-scans\local_ct_total_data\CT (49).nii
# ./aorta-ct-scans\local_ct_total_data\CT (5).nii
# ./aorta-ct-scans\local_ct_total_data\CT (50).nii
# ./aorta-ct-scans\local_ct_total_data\CT (51).nii
# ./aorta-ct-scans\local_ct_total_data\CT (6).nii
# ./aorta-ct-scans\local_ct_total_data\CT (7).nii
# ./aorta-ct-scans\local_ct_total_data\CT (8).nii
# ./aorta-ct-scans\local_ct_total_data\CT (9).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (1).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (10).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (11).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (12).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (13).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (14).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (15).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (16).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (17).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (18).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (19).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (2).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (20).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (21).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (22).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (23).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (24).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (25).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (26).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (27).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (28).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (29).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (3).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (30).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (31).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (32).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (33).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (34).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (35).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (36).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (37).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (38).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (39).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (4).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (40).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (41).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (42).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (43).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (44).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (45).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (46).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (47).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (48).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (49).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (5).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (50).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (51).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (6).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (7).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (8).nii
# ./aorta-ct-scans\local_segmentation_total_data\Segmentation (9).nii

# %%
'''def read_ct(path):
    image=nb.load(path)
    array=image.get_fdata()
    array=np.rot90(np.array(array,dtype=np.float32))
    return array'''
# Out:
# 'def read_ct(path):\n    image=nb.load(path)\n    array=image.get_fdata()\n    array=np.rot90(np.array(array,dtype=np.float32))\n    return array'

# %%
img_image=nb.load(CT_scans[10])
array_i=img_image.get_fdata()
array_i=np.rot90(np.array(array_i,dtype=np.float32))

# %%
mask_image=nb.load(Mask_scan[10])
array_m=mask_image.get_fdata()
array_m=np.rot90(np.array(array_m,dtype=np.float32))

# %%
data=pd.read_csv("./aorta-ct-scans/ct_segmentation_result.csv")

# %%
data
# Out:
#     Unnamed: 0                                         data_file  \
# 0            0   ./aorta-ct-scans/local_ct_total_data\CT (1).nii
# 1            1  ./aorta-ct-scans/local_ct_total_data\CT (10).nii
# 2            2  ./aorta-ct-scans/local_ct_total_data\CT (11).nii
# 3            3  ./aorta-ct-scans/local_ct_total_data\CT (12).nii
# 4            4  ./aorta-ct-scans/local_ct_total_data\CT (13).nii
# 5            5  ./aorta-ct-scans/local_ct_total_data\CT (14).nii
# 6            6  ./aorta-ct-scans/local_ct_total_data\CT (15).nii
# 7            7  ./aorta-ct-scans/local_ct_total_data\CT (16).nii
# 8            8  ./aorta-ct-scans/local_ct_total_data\CT (17).nii
# 9            9  ./aorta-ct-scans/local_ct_total_data\CT (18).nii
# 10          10  ./aorta-ct-scans/local_ct_total_data\CT (19).nii
# 11          11   ./aorta-ct-scans/local_ct_total_data\CT (2).nii
# 12          12  ./aorta-ct-scans/local_ct_total_data\CT (20).nii
# 13          13  ./aorta-ct-scans/local_ct_total_data\CT (21).nii
# 14          14  ./aorta-ct-scans/local_ct_total_data\CT (22).nii
# 15          15  ./aorta-ct-scans/local_ct_total_data\CT (23).nii
# 16          16  ./aorta-ct-scans/local_ct_total_data\CT (24).nii
# 17          17  ./aorta-ct-scans/local_ct_total_data\CT (25).nii
# 18          18  ./aorta-ct-scans/local_ct_total_data\CT (26).nii
# 19          19  ./aorta-ct-scans/local_ct_total_data\CT (27).nii
# 20          20  ./aorta-ct-scans/local_ct_total_data\CT (28).nii
# 21          21  ./aorta-ct-scans/local_ct_total_data\CT (29).nii
# 22          22   ./aorta-ct-scans/local_ct_total_data\CT (3).nii
# 23          23  ./aorta-ct-scans/local_ct_total_data\CT (30).nii
# 24          24  ./aorta-ct-scans/local_ct_total_data\CT (31).nii
# 25          25  ./aorta-ct-scans/local_ct_total_data\CT (32).nii
# 26          26  ./aorta-ct-scans/local_ct_total_data\CT (33).nii
# 27          27  ./aorta-ct-scans/local_ct_total_data\CT (34).nii
# 28          28  ./aorta-ct-scans/local_ct_total_data\CT (35).nii
# 29          29  ./aorta-ct-scans/local_ct_total_data\CT (36).nii
# 30          30  ./aorta-ct-scans/local_ct_total_data\CT (37).nii
# 31          31  ./aorta-ct-scans/local_ct_total_data\CT (38).nii
# 32          32  ./aorta-ct-scans/local_ct_total_data\CT (39).nii
# 33          33   ./aorta-ct-scans/local_ct_total_data\CT (4).nii
# 34          34  ./aorta-ct-scans/local_ct_total_data\CT (40).nii
# 35          35  ./aorta-ct-scans/local_ct_total_data\CT (41).nii
# 36          36  ./aorta-ct-scans/local_ct_total_data\CT (42).nii
# 37          37  ./aorta-ct-scans/local_ct_total_data\CT (43).nii
# 38          38  ./aorta-ct-scans/local_ct_total_data\CT (44).nii
# 39          39  ./aorta-ct-scans/local_ct_total_data\CT (45).nii
# 40          40  ./aorta-ct-scans/local_ct_total_data\CT (46).nii
# 41          41  ./aorta-ct-scans/local_ct_total_data\CT (47).nii
# 42          42  ./aorta-ct-scans/local_ct_total_data\CT (48).nii
# 43          43  ./aorta-ct-scans/local_ct_total_data\CT (49).nii
# 44          44   ./aorta-ct-scans/local_ct_total_data\CT (5).nii
# 45          45  ./aorta-ct-scans/local_ct_total_data\CT (50).nii
# 46          46  ./aorta-ct-scans/local_ct_total_data\CT (51).nii
# 47          47   ./aorta-ct-scans/local_ct_total_data\CT (6).nii
# 48          48   ./aorta-ct-scans/local_ct_total_data\CT (7).nii
# 49          49   ./aorta-ct-scans/local_ct_total_data\CT (8).nii
# 50          50   ./aorta-ct-scans/local_ct_total_data\CT (9).nii
#
#                                     segmentation_file
# 0   ./aorta-ct-scans/local_segmentation_total_data...
# 1   ./aorta-ct-scans/local_segmentation_total_data...
# 2   ./aorta-ct-scans/local_segmentation_total_data...
# 3   ./aorta-ct-scans/local_segmentation_total_data...
# 4   ./aorta-ct-scans/local_segmentation_total_data...
# 5   ./aorta-ct-scans/local_segmentation_total_data...
# 6   ./aorta-ct-scans/local_segmentation_total_data...
# 7   ./aorta-ct-scans/local_segmentation_total_data...
# 8   ./aorta-ct-scans/local_segmentation_total_data...
# 9   ./aorta-ct-scans/local_segmentation_total_data...
# 10  ./aorta-ct-scans/local_segmentation_total_data...
# 11  ./aorta-ct-scans/local_segmentation_total_data...
# 12  ./aorta-ct-scans/local_segmentation_total_data...
# 13  ./aorta-ct-scans/local_segmentation_total_data...
# 14  ./aorta-ct-scans/local_segmentation_total_data...
# 15  ./aorta-ct-scans/local_segmentation_total_data...
# 16  ./aorta-ct-scans/local_segmentation_total_data...
# 17  ./aorta-ct-scans/local_segmentation_total_data...
# 18  ./aorta-ct-scans/local_segmentation_total_data...
# 19  ./aorta-ct-scans/local_segmentation_total_data...
# 20  ./aorta-ct-scans/local_segmentation_total_data...
# 21  ./aorta-ct-scans/local_segmentation_total_data...
# 22  ./aorta-ct-scans/local_segmentation_total_data...
# 23  ./aorta-ct-scans/local_segmentation_total_data...
# 24  ./aorta-ct-scans/local_segmentation_total_data...
# 25  ./aorta-ct-scans/local_segmentation_total_data...
# 26  ./aorta-ct-scans/local_segmentation_total_data...
# 27  ./aorta-ct-scans/local_segmentation_total_data...
# 28  ./aorta-ct-scans/local_segmentation_total_data...
# 29  ./aorta-ct-scans/local_segmentation_total_data...
# 30  ./aorta-ct-scans/local_segmentation_total_data...
# 31  ./aorta-ct-scans/local_segmentation_total_data...
# 32  ./aorta-ct-scans/local_segmentation_total_data...
# 33  ./aorta-ct-scans/local_segmentation_total_data...
# 34  ./aorta-ct-scans/local_segmentation_total_data...
# 35  ./aorta-ct-scans/local_segmentation_total_data...
# 36  ./aorta-ct-scans/local_segmentation_total_data...
# 37  ./aorta-ct-scans/local_segmentation_total_data...
# 38  ./aorta-ct-scans/local_segmentation_total_data...
# 39  ./aorta-ct-scans/local_segmentation_total_data...
# 40  ./aorta-ct-scans/local_segmentation_total_data...
# 41  ./aorta-ct-scans/local_segmentation_total_data...
# 42  ./aorta-ct-scans/local_segmentation_total_data...
# 43  ./aorta-ct-scans/local_segmentation_total_data...
# 44  ./aorta-ct-scans/local_segmentation_total_data...
# 45  ./aorta-ct-scans/local_segmentation_total_data...
# 46  ./aorta-ct-scans/local_segmentation_total_data...
# 47  ./aorta-ct-scans/local_segmentation_total_data...
# 48  ./aorta-ct-scans/local_segmentation_total_data...
# 49  ./aorta-ct-scans/local_segmentation_total_data...
# 50  ./aorta-ct-scans/local_segmentation_total_data...

# %%
CT_scans=data["data_file"]
Mask_scan=data["segmentation_file"]

# %%
window_set = {'lung' : (-750-1500/2, -750+1500/2), 'abdomen' : (50-250/2, 50+250/2),
              'mediastinum' : (45-450/2, 45+450/2), 'bone' : (500-2000/2, 500+2000/2),
              'brain' : (40-70/2, 40+70/2), 'pelvis' : (45-300/2, 45+300/2)}

# %%
#img=read_ct(CT_scans[10])
img=array_i
#mask=read_ct(Mask_scan[10])
mask=array_m
plt.figure(figsize=(8, 8))
plt.imshow(img[...,180], cmap='gray', vmin=window_set['mediastinum'][0], vmax=window_set['mediastinum'][1])

plt.figure(figsize=(8, 8))
plt.imshow(mask[...,180],cmap='gray')
print(img.shape)
print(mask.shape)
# Out:
# (512, 512, 299)
# (512, 512, 299)

# %%
CT = []
Mask = []
img_size = 512


for case in range(len(data)): #Concat all cases to list
    ct = read_ct(CT_scans[case])
    mask = read_ct(Mask_scan[case])
    
    for imgsize in range(ct.shape[0]):        
        ct_img = cv2.resize(ct[imgsize], dsize = (img_size, img_size),interpolation = cv2.INTER_AREA).astype('uint8')
        mask_img = cv2.resize(mask[imgsize],dsize=(img_size, img_size),interpolation = cv2.INTER_AREA).astype('uint8')
        CT.append(ct_img[np.newaxis,...])
        Mask.append(mask_img[np.newaxis,...])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7916/270175028.py in <module>
#       5
#       6 for case in range(len(data)): #Concat all cases to list
# ----> 7     ct = read_ct(CT_scans[case])
#       8     mask = read_ct(Mask_scan[case])
#       9
#
# NameError: name 'read_ct' is not defined

# %%
CT=np.array(CT)
Mask=np.array(Mask)
mins = CT.min(axis=(1,2,3), keepdims=True)
maxs = CT.max(axis=(1,2,3), keepdims=True)
norm_data = (CT-mins)/(maxs-mins)
print(CT.shape)
print(Mask.shape)
#CT=CT.swapaxes(1,3)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7916/358571939.py in <module>
#       1 CT=np.array(CT)
#       2 Mask=np.array(Mask)
# ----> 3 mins = CT.min(axis=(1,2,3), keepdims=True)
#       4 maxs = CT.max(axis=(1,2,3), keepdims=True)
#       5 norm_data = (CT-mins)/(maxs-mins)
#
# C:\ProgramData\Anaconda3\envs\saynot\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      45
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
window_set = {'lung' : (-750-1500/2, -750+1500/2), 'abdomen' : (50-250/2, 50+250/2),
              'mediastinum' : (45-450/2, 45+450/2), 'bone' : (500-2000/2, 500+2000/2),
              'brain' : (40-70/2, 40+70/2), 'pelvis' : (45-300/2, 45+300/2)}

class IndexTracker:
    def __init__(self, ax, X, window='mediastinum'):
        self.ax = ax
        self.X = X
        #rows, self.cols, slices = X.shape
        self.rows, cols, slices = X.shape  #
        #height, width, channel = X.shape
        self.window = window_set[window]
        self.ind = 0 # set initial state
        
        #M = cv2.getRotationMatrix2D((width/2.0, height/2.0),90,1) #회전
        #self.X = cv2.warpAffine(self.X,M,(width,height)) #회전 다만 화면이 잘리고 늘려짐..
        #self.X = cv2.resize(self.X,(width,height), fx=10, fy=10)
        #self.X = cv2.resize(self.X, dsize=(width,height), interpolation=cv2.INTER_AREA)
        
        self.im = ax.imshow(self.X[self.ind,:,:], cmap='gray',vmin=window_set['mediastinum'][0], vmax=window_set['mediastinum'][1])

        #self.X[:,:,self.ind]
            
        
        self.update()
        
    def on_scroll(self, event):
        if event.button == 'up':
            # self.ind = (self.ind - 5) % self.slices
            self.ind = (self.ind - 1) % self.rows#
        else:
            # self.ind = (self.ind + 5) % self.slices
            self.ind = (self.ind + 1) % self.rows#
            
        self.update()
        
    def update(self):
        self.im.set_data(self.X[self.ind,:,:])#
        self.ax.set_ylabel('row %s' % self.ind)
        self.im.axes.figure.canvas.draw()
        
def plot3d(image, window='mediastinum', size=(8,8)):
    fig, ax = plt.subplots(1, 1, gridspec_kw=dict(top=1, bottom=0, left=0.08, right=0.96), figsize=size)
    tracker = IndexTracker(ax, image, window=window)
    fig.canvas.mpl_connect('scroll_event', tracker.on_scroll)
    plt.show()
    return tracker

# %%
# stack 2d images to create 3d volume

vol_array = np.array([img_image.get_fdata() for file in CT_scans])
vol_array = np.moveaxis(vol_array, 0, -1) #축을 새위치로 이동(0,-1)

print('Volume shape = {0}'.format(vol_array.shape))
# Out:
# Volume shape = (512, 512, 299, 51)

# %%
vol_array_reduction = np.squeeze(vol_array)

# %%
vol_array_reduction.shape
# Out:
# (512, 512, 299, 51)

# %%
vol_array[...,0].shape
# Out:
# (512, 512, 299)

# %%
# %matplotlib qt

# %%
plot3d(vol_array[...,0].T, window='mediastinum', size=(12,12))

# %%
class IndexTracker_m:
    def __init__(self, ax, X):
        self.ax = ax
        self.X = X
        #rows, self.cols, slices = X.shape
        self.rows, cols, slices = X.shape  #
        #height, width, channel = X.shape
        
        self.ind = 0 # set initial state
        
        #M = cv2.getRotationMatrix2D((width/2.0, height/2.0),90,1) #회전
        #self.X = cv2.warpAffine(self.X,M,(width,height)) #회전 다만 화면이 잘리고 늘려짐..
        #self.X = cv2.resize(self.X,(width,height), fx=10, fy=10)
        #self.X = cv2.resize(self.X, dsize=(width,height), interpolation=cv2.INTER_AREA)
        
        self.im = ax.imshow(self.X[self.ind,:,:],cmap='gray')

        #self.X[:,:,self.ind]
            
        
        self.update()
        
    def on_scroll(self, event):
        if event.button == 'up':
            # self.ind = (self.ind - 5) % self.slices
            self.ind = (self.ind - 1) % self.rows#
        else:
            # self.ind = (self.ind + 5) % self.slices
            self.ind = (self.ind + 1) % self.rows#
            
        self.update()
        
    def update(self):
        self.im.set_data(self.X[self.ind,:,:])#
        self.ax.set_ylabel('row %s' % self.ind)
        self.im.axes.figure.canvas.draw()
        
def plot3d_m(image, size=(8,8)):
    fig, ax = plt.subplots(1, 1, gridspec_kw=dict(top=1, bottom=0, left=0.08, right=0.96), figsize=size)
    tracker = IndexTracker_m(ax, image)
    fig.canvas.mpl_connect('scroll_event', tracker.on_scroll)
    plt.show()
    return tracker

# %%
# stack 2d images to create 3d volume

vol_array_m = np.array([mask_image.get_fdata() for file in CT_scans])
vol_array_m = np.moveaxis(vol_array_m, 0, -1) #축을 새위치로 이동(0,-1)

print('Volume shape = {0}'.format(vol_array_m.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7916/2138675013.py in <module>
#       4 vol_array_m = np.moveaxis(vol_array_m, 0, -1) #축을 새위치로 이동(0,-1)
#       5
# ----> 6 print('Volume shape = {0}'.format(vol_array.shape))
#
# NameError: name 'vol_array' is not defined

# %%
vol_array_m[...,0].shape
# Out:
# (512, 512, 299)

# %%
# %matplotlib qt

# %%
plot3d_m(vol_array_m[...,0].T, size=(12,12))

# %% [markdown]
# ## (2) Define train/validation set

# %%
class CT_dataset(keras.utils.Sequence):
    def __init__(self, CT,Mask):
        self.ct_scans =CT
        self.mask_scan = Mask

    def __len__(self):
        return len(self.ct_scans)

    def __getitem__(self, idx):
        ct=self.ct_scans[idx]
        masks=self.mask_scan[idx]
        return ct,masks

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(norm_data,Mask,test_size=0.2,random_state=42)

# %%
##임의수정 x_train,x_test,y_train,y_test
x_train=x_train.swapaxes(1,3)
y_train=y_train.swapaxes(1,3)
x_test=x_test.swapaxes(1,3)
y_test=y_test.swapaxes(1,3)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (20889, 512, 512, 1)
# (20889, 512, 512, 1)
# (5223, 512, 512, 1)
# (5223, 512, 512, 1)

# %%
train_dataset=CT_dataset(x_train,y_train)
test_dataset=CT_dataset(x_test,y_test)

# %%
import numpy as np
import math
from tensorflow.keras.utils import Sequence

class Dataloader(Sequence):

    def __init__(self, x_set, y_set, batch_size, shuffle=False):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size
        self.shuffle=shuffle
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.x) / self.batch_size)

		# batch 단위로 직접 묶어줘야 함
    def __getitem__(self, idx):
				# sampler의 역할(index를 batch_size만큼 sampling해줌)
        indices = self.indices[idx*self.batch_size:(idx+1)*self.batch_size]

        batch_x = [self.x[i] for i in indices]
        batch_y = [self.y[i] for i in indices]

        return np.array(batch_x), np.array(batch_y)

    # epoch이 끝날때마다 실행
    def on_epoch_end(self):
        self.indices = np.arange(len(self.x))
        if self.shuffle == True:
            np.random.shuffle(self.indices)
            

train_dl = Dataloader(x_train,y_train, 4, shuffle=True)
valid_dl = Dataloader(x_test,y_test, 1, shuffle=False)

# %%
image,label=train_dataset[:]
image=image.swapaxes(1,3)
label=label.swapaxes(1,3)
print(image.shape)
print(label.shape)
plt.imshow(image[20000].squeeze(0).T) 
plt.figure()
plt.imshow(label[20000].squeeze(0).T)
# Out:
# (20889, 1, 512, 512)
# (20889, 1, 512, 512)

# %% [markdown]
# # #Advanced visualization

# %%
class IndexTracker:
    def __init__(self, ax, X, window='mediastinum'):
        self.ax = ax
        self.X = X
        #rows, self.cols, slices = X.shape
        rows, cols, self.slices = X.shape  #
        height, width, channel = X.shape
        self.window = window_set[window]
        self.ind = 0 # set initial state
        
        M = cv2.getRotationMatrix2D((width/2.0, height/2.0),90,1) #회전
        self.X = cv2.warpAffine(self.X,M,(width,height)) #회전 다만 화면이 잘리고 늘려짐..
        self.X = cv2.resize(self.X,(width,height), fx=10, fy=10)
        #self.X = cv2.resize(self.X, dsize=(width,height), interpolation=cv2.INTER_AREA)
        
        self.im = ax.imshow(self.X[:,:,self.ind], cmap='gray', vmin=self.window[0], vmax=self.window[1])

        #self.X[:,:,self.ind]
            
        
        self.update()
        
    def on_scroll(self, event):
        if event.button == 'up':
            # self.ind = (self.ind - 5) % self.slices
            self.ind = (self.ind - 5) % self.slices#
        else:
            # self.ind = (self.ind + 5) % self.slices
            self.ind = (self.ind + 5) % self.slices#
            
        self.update()
        
    def update(self):
        self.im.set_data(self.X[:,:,self.ind])#
        self.ax.set_ylabel('slice %s' % self.ind)
        self.im.axes.figure.canvas.draw()

# %%
        
def plot3d(image, window='mediastinum', size=(8,8)):
    fig, ax = plt.subplots(1, 1, gridspec_kw=dict(top=1, bottom=0, left=0.08, right=0.96), figsize=size)
    tracker = IndexTracker(ax, image, window=window)
    fig.canvas.mpl_connect('scroll_event', tracker.on_scroll)
    plt.show()
    return tracker

# %%
import glob
nii_directory = './aorta-ct-scans/local_ct_total_data'

nii_filelist = [os.path.join(nii_directory, file) for file in os.listdir(nii_directory) if file.endswith('nii')]

#print('number of slices : {0}'.format(len(nii_filelist)))
#test = nib.read_file(nii_filelist[0])


nii_file = glob.glob(os.path.join(nii_directory, '*.nii'))
nii_file = nii_file[0]

nii1 = nb.load(nii_file)

# %%
# stack 2d images to create 3d volume

#vol_array = np.array([pydicom.read_file(file).pixel_array for file in CT_scans])
nii1.dataobj[...,0]
vol_array = np.array([nii1.dataobj[...,0] for file in CT_scans])
vol_array = np.moveaxis(vol_array, -1, 0) #축을 새위치로 이동(0,-1)

print('Volume shape = {0}'.format(vol_array.shape))
# Out:
# Volume shape = (512, 51, 512)

# %%
nii1 = nii1.swapaxes(1,2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2204/1548928959.py in <module>
# ----> 1 nii1 = nii1.swapaxes(1,2)
#
# AttributeError: 'Nifti1Image' object has no attribute 'swapaxes'

# %%
advance 시각화에서  swap이 안되는 문제
안하고 모델학습 시켜도 되는데 그러면 결과가 무의미해짐

# %%
nii1.shape
# Out:
# (299, 512, 512)

# %%
# Visualize image in new window

# %matplotlib qt

# %%
plot3d(nii1[1], window='mediastinum', size=(15,15))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15104/379593742.py in <module>
# ----> 1 plot3d(nii1[1], window='mediastinum', size=(15,15))
#
# ~\AppData\Local\Temp/ipykernel_15104/623887724.py in plot3d(image, window, size)
#       1 def plot3d(image, window='mediastinum', size=(8,8)):
#       2     fig, ax = plt.subplots(1, 1, gridspec_kw=dict(top=1, bottom=0, left=0.08, right=0.96), figsize=size)
# ----> 3     tracker = IndexTracker(ax, image, window=window)
#       4     fig.canvas.mpl_connect('scroll_event', tracker.on_scroll)
#       5     plt.show()
#
# ~\AppData\Local\Temp/ipykernel_15104/4244637287.py in __init__(self, ax, X, window)
#       4         self.X = X
#       5         #rows, self.cols, slices = X.shape
# ----> 6         rows, cols, self.slices = X.shape  #
#       7         height, width, channel = X.shape
#       8         self.window = window_set[window]
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# ## (3) Build and train a model

# %% [markdown]
# ### Method 1 : U-Net

# %%
# U-Net : https://arxiv.org/abs/1505.04597
# input shape = output shape : (batch_size, 512, 512, 1)

def unet():
    # encoding + decoding layer with skip connection
    # Fully convolutional network without dense layer 
    # FCN : https://www.cv-foundation.org/openaccess/content_cvpr_2015/papers/Long_Fully_Convolutional_Networks_2015_CVPR_paper.pdf
    
    # tf.keras.layers.Conv2D
    # tf.keras.layers.MaxPool2D
    # tf.keras.layers.BatchNormalization
    # tf.keras.layers.ReLu
    # tf.keras.layers.Conv2DTranspose or tf.keras.layers.UpSampling2D + tf.keras.layers.Conv2D
    # tf.concat
    # Sigmoid activation at last layer
    
    ...
    ...
    
    return model

# %%
from sklearn.model_selection import train_test_split,StratifiedKFold


from tensorflow.keras.layers import Dense, Input, Activation, Flatten
from tensorflow.keras.layers import BatchNormalization,Add,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import LeakyReLU, ReLU, Conv2D, MaxPooling2D, BatchNormalization, Conv2DTranspose, UpSampling2D, concatenate
from tensorflow.keras import callbacks
from tensorflow.keras import backend as K

# %%
def UNet(pretrained_weights = None,input_size = (512,512,1)):
    inp = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inp)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = Model(inputs = inp, outputs=[conv10])

    return model

# %%
model = UNet()
model.summary()
model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 64)   640         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 64)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 512)    1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 512)    2359808     ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 8, 8, 512)    0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 512)   0           ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 1024)   4719616     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 1024)   9438208     ['conv2d_8[0][0]']
#
#  dropout_1 (Dropout)            (None, 4, 4, 1024)   0           ['conv2d_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 1024)   0           ['dropout_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 512)    2097664     ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 1024)   0           ['dropout[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 512)    4719104     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 512)    2359808     ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 512)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 256)  524544      ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 512)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0          ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 128)  131200      ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 64)   32832       ['up_sampling2d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 2)    1154        ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 1)    3           ['conv2d_22[0][0]']
#
# ==================================================================================================
# Total params: 31,031,685
# Trainable params: 31,031,685
# Non-trainable params: 0
# __________________________________________________________________________________________________
# C:\ProgramData\Anaconda3\envs\saynot\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs = 10)
# Out:
# Epoch 1/10
# 653/653 [==============================] - 32s 46ms/step - loss: 0.0033 - accuracy: 0.9998 - val_loss: 9.7211e-04 - val_accuracy: 0.9998
# Epoch 2/10
# 653/653 [==============================] - 30s 46ms/step - loss: 7.5018e-04 - accuracy: 0.9998 - val_loss: 7.4709e-04 - val_accuracy: 0.9998
# Epoch 3/10
# 653/653 [==============================] - 30s 46ms/step - loss: 6.7570e-04 - accuracy: 0.9998 - val_loss: 7.6648e-04 - val_accuracy: 0.9998
# Epoch 4/10
# 653/653 [==============================] - 30s 47ms/step - loss: 6.1988e-04 - accuracy: 0.9998 - val_loss: 5.8405e-04 - val_accuracy: 0.9998
# Epoch 5/10
# 653/653 [==============================] - 30s 46ms/step - loss: 5.5157e-04 - accuracy: 0.9998 - val_loss: 5.4858e-04 - val_accuracy: 0.9998
# Epoch 6/10
# 653/653 [==============================] - 30s 46ms/step - loss: 4.6399e-04 - accuracy: 0.9998 - val_loss: 4.8089e-04 - val_accuracy: 0.9998
# Epoch 7/10
# 653/653 [==============================] - 30s 47ms/step - loss: 4.0170e-04 - accuracy: 0.9998 - val_loss: 4.0762e-04 - val_accuracy: 0.9998
# Epoch 8/10
# 653/653 [==============================] - 30s 47ms/step - loss: 3.4343e-04 - accuracy: 0.9999 - val_loss: 3.7181e-04 - val_accuracy: 0.9999
# Epoch 9/10
# 653/653 [==============================] - 30s 46ms/step - loss: 3.1157e-04 - accuracy: 0.9999 - val_loss: 3.4527e-04 - val_accuracy: 0.9999
# Epoch 10/10
# 653/653 [==============================] - 30s 46ms/step - loss: 2.8795e-04 - accuracy: 0.9999 - val_loss: 3.4905e-04 - val_accuracy: 0.9999

# %%
model.evaluate(x_test, y_test)
# Out:
# 164/164 [==============================] - 2s 13ms/step - loss: 3.4905e-04 - accuracy: 0.9999
# [0.00034905425854958594, 0.9998689293861389]

# %%
from keras.models import model_from_json
model_json = model.to_json()

with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
##임의수정 x_train,x_test,y_train,y_test
x_train=x_train.swapaxes(1,3)
y_train=y_train.swapaxes(1,3)
x_test=x_test.swapaxes(1,3)
y_test=y_test.swapaxes(1,3)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (20889, 64, 64, 1)
# (20889, 64, 64, 1)
# (5223, 64, 64, 1)
# (5223, 64, 64, 1)

# %%
training_pred = model.predict(x_train)
testing_pred = model.predict(x_test)

# %%
def prediction(X, y, pred, k=None):
    if k  == 'None':
        k = np.random.randint(0, len(X))

    has_mask = y[k].max() > 0

    figure, j = plt.subplots(1, 3, figsize=(20, 20))
    j[0].imshow(X[k, ..., 0])
    if has_mask:
        j[0].contour(y[i].squeeze())
    k[1].imshow(y[i].squeeze())
    k[2].imshow(pred[i].squeeze())
    if has_mask:
        k[2].contour(preds[i].squeeze())

# %%
prediction(x_train, y_train,training_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11832/4247757.py in <module>
# ----> 1 prediction(x_train, y_train,training_pred)
#
# ~\AppData\Local\Temp/ipykernel_11832/1429308939.py in prediction(X, y, pred, k)
#       6
#       7     figure, j = plt.subplots(1, 3, figsize=(20, 20))
# ----> 8     j[0].imshow(X[k, ..., 0])
#       9     if has_mask:
#      10         j[0].contour(y[i].squeeze())
#
# C:\ProgramData\Anaconda3\envs\saynot\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\envs\saynot\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5607                               resample=resample, **kwargs)
#    5608
# -> 5609         im.set_data(X)
#    5610         im.set_alpha(alpha)
#    5611         if im.get_clip_path() is None:
#
# C:\ProgramData\Anaconda3\envs\saynot\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     707         if not (self._A.ndim == 2
#     708                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 709             raise TypeError("Invalid shape {} for image data"
#     710                             .format(self._A.shape))
#     711
#
# TypeError: Invalid shape (1, 20889, 64, 64) for image data

# %%
xhat = x_test[0:1]
yhat = model.predict(xhat)

#print(yhat)

# %%
plt.imshow(xhat[0,...], cmap='gray', vmin=window_set['mediastinum'][0], vmax=window_set['mediastinum'][1])
plt.figure()
plt.imshow(yhat[0,...], cmap='gray', vmin=window_set['mediastinum'][0], vmax=window_set['mediastinum'][1])

# %%
plt.imshow(xhat[0,...])
plt.figure()
plt.imshow(yhat[0,...])
#plt.imshow(yhat.squeeze(0))

# %% [markdown]
# ### Method 2 : 3D U-Net

# %%
# 3D Unet : https://arxiv.org/abs/1606.06650
# input shape : (batch_size, 512, 512, height, 1)

def unet_3D():
    
    # tf.keras.layers.Conv3D
    # tf.keras.layers.MaxPool3D
    # tf.keras.layers.BatchNormalization
    # tf.keras.layers.ReLu
    # tf.keras.layers.Conv3DTranspose or tf.keras.layers.UpSampling3D + tf.keras.layers.Conv3D
    # tf.concat
    # Sigmoid activation at last layer
    
    ...
    ...
    
    return model

# %%
# define a optimizer/metrics and compile the model

model.compile(...)


# print summary of this model
model.summary()

# %%
# Start training

model_history = model.fit(...)

# %% [markdown]
# ## (4) Plot loss and metrics

# %%
model_history.epoch
model_history.history

# %% [markdown]
# ## (5) Predict on test set images

# %%
model.predict()

# %% [markdown]
# ## (6) Saving & loading the trained model

# %%
model.save(...)

# %% [markdown]
# ## (7) Debugging model/dataset
